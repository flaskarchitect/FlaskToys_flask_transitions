# %%
locate *.mp3
# Out:
# /home/jack/.config/google-chrome/Default/Extensions/nabkmoilefdjaomjhjbobkklkikooapi/1.7.14_0/audio/beep.mp3
# /home/jack/.config/google-chrome/Default/Extensions/nabkmoilefdjaomjhjbobkklkikooapi/1.7.14_0/audio/lowbeep.mp3
# /home/jack/.config/spyder-py3/center-100x100TEMP_MPY_wvf_snd.mp3
# /home/jack/.local/share/Steam/tenfoot/resource/sounds/ambient/amb_bigfoot_backing_drone_01.mp3
# /home/jack/.local/share/Steam/tenfoot/resource/sounds/ambient/amb_bigfoot_backing_part_01_01.mp3
# /home/jack/.local/share/Steam/tenfoot/resource/sounds/ambient/amb_bigfoot_backing_part_01_02.mp3
# /home/jack/.local/share/Steam/tenfoot/resource/sounds/ambient/amb_bigfoot_backing_part_01_03.mp3
# /home/jack/.local/share/Steam/tenfoot/resource/sounds/ambient/amb_bigfoot_backing_part_01_04.mp3
# /home/jack/.local/share/Steam/tenfoot/resource/sounds/ambient/amb_bigfoot_backing_part_01_05.mp3
# /home/jack/.local/share/Steam/tenfoot/resource/sounds/ambient/amb_bigfoot_backing_part_01_06.mp3
# ...

# %%
images=/home/jack/Desktop/HDD500/collections/images/Dali_woman/
melt \
$images/.all.jpg ttl=75 \
-attach crop center=1 \
-attach affine transition.cycle=225 transition.geometry="0=0/0:100%x100%;74=-100/-100:120%x120%;75=-60/-60:110%x110%;149=0/0:110%x110%;150=0/-60:110%x110%;224=-60/0:110%x110%" \
-filter luma cycle=75 duration=25 \
-track /home/jack/Desktop/Ffmpeg/Cambodian-Odyssey/Odyssey.mp3 \
-transition mix \
 -consumer avformat:${suf}_Test_video.mp4
# Out:
# [mp3 @ 0x55776b9982c0] Estimating duration from bitrate, this may be inaccurate
# [mp3 @ 0x55776b9a7900] Estimating duration from bitrate, this may be inaccurate
# [mp3 @ 0x55776b9a7900] Value 1.000000 for parameter 'seekable' out of range [-1 - 0]
# [mp3 @ 0x55776b9a7900] Estimating duration from bitrate, this may be inaccurate
# [mp3 @ 0x55776b9dee40] Estimating duration from bitrate, this may be inaccurate
# [mp3 @ 0x55776bbb9c00] Estimating duration from bitrate, this may be inaccurate
# [mp3 @ 0x55776b9d5d40] Estimating duration from bitrate, this may be inaccurate
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# |1=-10| |2= -5| |3= -2| |4= -1| |5=  0| |6=  1| |7=  2| |8=  5| |9= 10|
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# +---------------------------------------------------------------------+
# |               H = back 1 minute,  L = forward 1 minute              |
# ...

# %%
#!/bin/bash

# Set the path to your image directory
images="/home/jack/Desktop/HDD500/collections/images/Dali_woman/"

# Set the output resolution
output_resolution="512x768"

# Set the output video file path
output_file="${images}/512x768_output_video.mp4"

# Logging start
echo "Starting video processing..."

# Run melt command
melt \
"${images}/.all.jpg" ttl=75 \
-attach crop center=1 \
-attach affine transition.cycle=225 transition.geometry="0=0/0:100%x100%;74=-100/-100:120%x120%;75=-60/-60:110%x110%;149=0/0:110%x110%;150=0/-60:110%x110%;224=-60/0:110%x110%" \
-filter luma cycle=75 duration=25 \
-track /home/jack/Desktop/Ffmpeg/Cambodian-Odyssey/Odyssey.mp3 \
-transition mix \
-consumer avformat:"${output_file}" s=${output_resolution}

# Logging end
echo "Video processing complete. Output saved at: ${output_file}"
vlc ${output_file}
# Out:
# Starting video processing...
# [mp3 @ 0x558c4afae440] Estimating duration from bitrate, this may be inaccurate
# [mp3 @ 0x558c4afaf280] Estimating duration from bitrate, this may be inaccurate
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# |1=-10| |2= -5| |3= -2| |4= -1| |5=  0| |6=  1| |7=  2| |8=  5| |9= 10|
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# +---------------------------------------------------------------------+
# |               H = back 1 minute,  L = forward 1 minute              |
# |                 h = previous frame,  l = next frame                 |
# |           g = start of clip, j = next clip, k = previous clip       |
# |                0 = restart, q = quit, space = play                  |
# +---------------------------------------------------------------------+
# [libx264 @ 0x7f2d2c001d00] interlace + weightp is not implemented
# ...

# %%
#!/bin/bash

# Set the path to your image directory
images="/home/jack/Desktop/HDD500/collections/images/Dali_woman/"

# Set the output resolution
output_resolution="512x768"

# Set the output video file path
output_file="${images}/512x768_output_video.mp4"

# Logging start
echo "Starting video processing..."

# Run melt command
melt \
"${images}/.all.jpg" ttl=75 \
-attach crop center=1 \
-attach affine transition.cycle=225 transition.geometry="0=0/0:100%x100%;74=-100/-100:120%x120%;75=-60/-60:110%x110%;149=0/0:110%x110%;150=0/-60:110%x110%;224=-60/0:110%x110%" \
-filter luma cycle=75 duration=25 \
-track /home/jack/Desktop/Ffmpeg/Cambodian-Odyssey/Odyssey.mp3 \
-transition mix \
-consumer avformat:"${output_file}" s=${output_resolution}

# Logging end
echo "Video processing complete. Output saved at: ${output_file}"
vlc ${output_file}
# Out:
# Starting video processing...
# [mp3 @ 0x558c4afae440] Estimating duration from bitrate, this may be inaccurate
# [mp3 @ 0x558c4afaf280] Estimating duration from bitrate, this may be inaccurate
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# |1=-10| |2= -5| |3= -2| |4= -1| |5=  0| |6=  1| |7=  2| |8=  5| |9= 10|
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# +---------------------------------------------------------------------+
# |               H = back 1 minute,  L = forward 1 minute              |
# |                 h = previous frame,  l = next frame                 |
# |           g = start of clip, j = next clip, k = previous clip       |
# |                0 = restart, q = quit, space = play                  |
# +---------------------------------------------------------------------+
# [libx264 @ 0x7f2d2c001d00] interlace + weightp is not implemented
# ...

# %%
#!/bin/bash

# Set the path to your image directory
images="/home/jack/Desktop/HDD500/collections/images/Dali_woman/"

# Set the output resolution
output_resolution="512x768"

# Set the output video file path
output_file="${images}/512x768_output_video.mp4"

# Logging start
echo "Starting video processing..."

# Run melt command
melt \
"${images}/.all.jpg" ttl=75 \
-attach crop center=1 \
-attach affine transition.cycle=225 transition.geometry="0=0/0:100%x100%;74=-10%/-10%:120%x120%;75=-5%/-5%:110%x110%;149=0/0:110%x110%;150=0/-5%:110%x110%;224=-5%/0:110%x110%" \
-filter luma cycle=75 duration=25 \
-track /home/jack/Desktop/Ffmpeg/Cambodian-Odyssey/Odyssey.mp3 \
-transition mix \
-consumer avformat:"${output_file}" s=${output_resolution}

# Logging end
echo "Video processing complete. Output saved at: ${output_file}"
vlc ${output_file}
# Out:
# Starting video processing...
# [mp3 @ 0x5641e05731c0] Estimating duration from bitrate, this may be inaccurate
# [mp3 @ 0x5641e0582900] Estimating duration from bitrate, this may be inaccurate
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# |1=-10| |2= -5| |3= -2| |4= -1| |5=  0| |6=  1| |7=  2| |8=  5| |9= 10|
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# +---------------------------------------------------------------------+
# |               H = back 1 minute,  L = forward 1 minute              |
# |                 h = previous frame,  l = next frame                 |
# |           g = start of clip, j = next clip, k = previous clip       |
# |                0 = restart, q = quit, space = play                  |
# +---------------------------------------------------------------------+
# [libx264 @ 0x7f24b0001d00] interlace + weightp is not implemented
# ...

# %%
vlc _Test_video.mp4
# Out:
# VLC media player 3.0.11.1 Vetinari (revision 3.0.11.1-0-g52483f3ca2)
# [0000000000973ec0] main libvlc: Running vlc with the default interface. Use 'cvlc' to use vlc without interface.
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# libva info: Trying to open /usr/lib/x86_64-linux-gnu/dri/nouveau_drv_video.so
# libva error: /usr/lib/x86_64-linux-gnu/dri/nouveau_drv_video.so has no function __vaDriverInit_0_32
# libva info: va_openDriver() returns -1
# [00007f6ef4001840] glconv_vaapi_x11 gl error: vaInitialize: unknown libva error
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# libva info: Trying to open /usr/lib/x86_64-linux-gnu/dri/gallium_drv_video.so
# libva info: va_openDriver() returns -1
# [00007f6ef4001840] glconv_vaapi_drm gl error: vaInitialize: unknown libva error
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# ...

# %%
melt \
all4.mp4 out=1000 \
-track \
logo.png out=1000 \
-transition composite fill=1 in=0 out=1000 a_track=0 b_track=1 geometry=85%/5%:10%x10% sliced_composite=1 \
 -consumer avformat:${suf}_watermarked_video.mp4
# Out:
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x5582a7f4f580] Value 1.000000 for parameter 'seekable' out of range [-1 - 0]
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x5582a81659c0] Value 1.000000 for parameter 'seekable' out of range [-1 - 0]
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x5582a81a6000] Value 1.000000 for parameter 'seekable' out of range [-1 - 0]
# [swscaler @ 0x5582a8516380] Warning: data is not aligned! This can lead to a speed loss
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x5582a7e7aa00] Value 1.000000 for parameter 'seekable' out of range [-1 - 0]
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# |1=-10| |2= -5| |3= -2| |4= -1| |5=  0| |6=  1| |7=  2| |8=  5| |9= 10|
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# +---------------------------------------------------------------------+
# |               H = back 1 minute,  L = forward 1 minute              |
# |                 h = previous frame,  l = next frame                 |
# ...

# %%
all4.mp4

# %%
ls *.png
# Out:
# comic_frame_b-512x768.png  logo.png

# %%
ls -rant *.mp4
# Out:
# -rw-rw-r-- 1 1000 1000 33796426 Nov 23 05:32 All_gifs2.mp4
# -rw-rw-r-- 1 1000 1000 22698387 Nov 23 05:32 xxxxoutput.mp4
# -rw-rw-r-- 1 1000 1000   668438 Nov 26 15:49 start.mp4
# -rw-rw-r-- 1 1000 1000   777572 Nov 26 15:49 output2.mp4
# -rw-rw-r-- 1 1000 1000  3121827 Nov 26 15:51 final2l.mp4
# -rw-rw-r-- 1 1000 1000  5979778 Nov 26 15:56 final5l.mp4
# -rw-rw-r-- 1 1000 1000  3043772 Nov 27 18:54 AI_Creates_Beautiful_Women.mp4
# -rw-rw-r-- 1 1000 1000   357386 Dec  8 21:11 0.mp4
# -rw-rw-r-- 1 1000 1000   359985 Dec  8 21:11 1.mp4
# -rw-rw-r-- 1 1000 1000   333999 Dec  8 21:11 2.mp4
# -rw-rw-r-- 1 1000 1000   345101 Dec  8 21:11 3.mp4
# -rw-rw-r-- 1 1000 1000   360564 Dec  8 21:11 4.mp4
# -rw-rw-r-- 1 1000 1000   361190 Dec  8 21:11 5.mp4
# -rw-rw-r-- 1 1000 1000   359414 Dec  8 21:11 6.mp4
# -rw-rw-r-- 1 1000 1000   351810 Dec  8 21:11 7.mp4
# -rw-rw-r-- 1 1000 1000   348241 Dec  8 21:11 8.mp4
# -rw-rw-r-- 1 1000 1000   343815 Dec  8 21:11 9.mp4
# ...

# %%
vlc _watermarked_video.mp4
# Out:
# VLC media player 3.0.11.1 Vetinari (revision 3.0.11.1-0-g52483f3ca2)
# [0000000001328ec0] main libvlc: Running vlc with the default interface. Use 'cvlc' to use vlc without interface.
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# libva info: Trying to open /usr/lib/x86_64-linux-gnu/dri/nouveau_drv_video.so
# libva error: /usr/lib/x86_64-linux-gnu/dri/nouveau_drv_video.so has no function __vaDriverInit_0_32
# libva info: va_openDriver() returns -1
# [00007f46cc001840] glconv_vaapi_x11 gl error: vaInitialize: unknown libva error
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# libva info: Trying to open /usr/lib/x86_64-linux-gnu/dri/gallium_drv_video.so
# libva info: va_openDriver() returns -1
# [00007f46cc001840] glconv_vaapi_drm gl error: vaInitialize: unknown libva error
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# ...

# %%
ls -rant
# Out:
# total 121724
# -rwxrwxr-x  1 1000 1000     2652 Nov 15 17:52 PadEffect
# -rwxrwxr-x  1 1000 1000     3168 Nov 18 00:03 blendem
# -rwxrwxr-x  1 1000 1000     2403 Nov 18 00:05 app.py
# -rw-rw-r--  1 1000 1000      838 Nov 19 06:34 speed.py
# -rwxrwxr-x  1 1000 1000     3705 Nov 19 09:52 overlay_pad
# -rwxrwxr-x  1 1000 1000      816 Nov 20 02:55 image_show.py
# -rwxrwxr-x  1 1000 1000     2021 Nov 20 07:12 SuperEffectl
# -rwxrwxr-x  1 1000 1000     2874 Nov 20 08:16 minterpolate.py
# -rwxrwxr-x  1 1000 1000    18226 Nov 22 15:19 zoom_overlay
# -rw-rw-r--  1 1000 1000      112 Nov 23 05:01 README.md
# -rw-rw-r--  1 1000 1000     7048 Nov 23 05:01 LICENSE
# drwxrwxr-x  7 1000 1000     4096 Nov 23 05:03 static
# drwxrwxr-x  2 1000 1000     4096 Nov 23 05:03 debug_test
# -rw-rw----  1 1000 1000       42 Nov 23 05:32 .gitattributes
# -rw-rw-r--  1 1000 1000 33796426 Nov 23 05:32 All_gifs2.mp4
# -rw-rw-r--  1 1000 1000 22698387 Nov 23 05:32 xxxxoutput.mp4
# ...

# %%
# exp
# Get the current date and time
suf=$(date +'%Y%m%d%H%M%S')
melt color:blue in=0 out=320 -track logo.png in=0 out=320 -transition affine valign=middle halign=center scale=1 fill=1 
geometry="0=10%,10%:80%x80%:0%;60=0,0:100%x100%:100%;260=-10%,-10%:120%x120%:100%;320=-10%,-10%:120%x120%:0%"
-consumer avformat:${suf}_video_alt.mp4
vlc ${suf}_video_alt.mp4
# Out:
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# |1=-10| |2= -5| |3= -2| |4= -1| |5=  0| |6=  1| |7=  2| |8=  5| |9= 10|
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# +---------------------------------------------------------------------+
# |               H = back 1 minute,  L = forward 1 minute              |
# |                 h = previous frame,  l = next frame                 |
# |           g = start of clip, j = next clip, k = previous clip       |
# |                0 = restart, q = quit, space = play                  |
# +---------------------------------------------------------------------+
# Current Position:        136
# bash: transition.geometry=0=0/0:100%x100%;74=-10%/-10%:120%x120%;75=-5%/-5%:110%x110%;149=0/0:110%x110%;150=0/-5%:110%x110%;224=-5%/0:110%x110%: No such file or directory
# -consumer: command not found
# VLC media player 3.0.11.1 Vetinari (revision 3.0.11.1-0-g52483f3ca2)
# ...

# %%
melt -query filters >melt.filters

# %%
cat melt.filters
# Out:
# ---
# filters:
#   - frei0r.3dflippo
#   - frei0r.B
#   - frei0r.G
#   - frei0r.IIRblur
#   - frei0r.R
#   - frei0r.alpha0ps
#   - frei0r.alphagrad
#   - frei0r.alphaspot
#   - frei0r.balanc0r
#   - frei0r.baltan
#   - frei0r.bgsubtract0r
#   - frei0r.bluescreen0r
#   - frei0r.brightness
#   - frei0r.bw0r
#   - frei0r.c0rners
#   - frei0r.cairogradient
#   - frei0r.cairoimagegrid
#   - frei0r.cartoon
#   - frei0r.cluster
#   - frei0r.colgate
#   - frei0r.coloradj_RGB
#   - frei0r.colordistance
#   - frei0r.colorhalftone
#   - frei0r.colorize
#   - frei0r.colortap
#   - frei0r.contrast0r
#   - frei0r.curves
#   - frei0r.d90stairsteppingfix
#   - frei0r.defish0r
#   - frei0r.delay0r
#   - frei0r.delaygrab
#   - frei0r.distort0r
#   - frei0r.dither
#   - frei0r.edgeglow
#   - frei0r.elastic_scale
#   - frei0r.emboss
#   - frei0r.equaliz0r
#   - frei0r.flippo
#   - frei0r.gamma
#   - frei0r.glitch0r
#   - frei0r.glow
#   - frei0r.hqdn3d
#   - frei0r.hueshift0r
#   - frei0r.invert0r
# ...

# %%
linez = open("melt.filters").read()
lines = linez.split("\n")
for data in lines:
    print (data, end =" ")
# Out:
# --- filters:   - frei0r.3dflippo   - frei0r.B   - frei0r.G   - frei0r.IIRblur   - frei0r.R   - frei0r.alpha0ps   - frei0r.alphagrad   - frei0r.alphaspot   - frei0r.balanc0r   - frei0r.baltan   - frei0r.bgsubtract0r   - frei0r.bluescreen0r   - frei0r.brightness   - frei0r.bw0r   - frei0r.c0rners   - frei0r.cairogradient   - frei0r.cairoimagegrid   - frei0r.cartoon   - frei0r.cluster   - frei0r.colgate   - frei0r.coloradj_RGB   - frei0r.colordistance   - frei0r.colorhalftone   - frei0r.colorize   - frei0r.colortap   - frei0r.contrast0r   - frei0r.curves   - frei0r.d90stairsteppingfix   - frei0r.defish0r   - frei0r.delay0r   - frei0r.delaygrab   - frei0r.distort0r   - frei0r.dither   - frei0r.edgeglow   - frei0r.elastic_scale   - frei0r.emboss   - frei0r.equaliz0r   - frei0r.flippo   - frei0r.gamma   - frei0r.glitch0r   - frei0r.glow   - frei0r.hqdn3d   - frei0r.hueshift0r   - frei0r.invert0r   - frei0r.keyspillm0pup   - frei0r.lenscorrection   - frei0r.letterb0xed   - frei0r.levels   -
# ...

# %%
melt -query transitions
# Out:
# ---
# transitions:
#   - frei0r.addition
#   - frei0r.addition_alpha
#   - frei0r.alphaatop
#   - frei0r.alphain
#   - frei0r.alphainjection
#   - frei0r.alphaout
#   - frei0r.alphaover
#   - frei0r.alphaxor
#   - frei0r.blend
#   - frei0r.burn
#   - frei0r.cairoaffineblend
#   - frei0r.cairoblend
#   - frei0r.color_only
#   - frei0r.composition
#   - frei0r.darken
#   - frei0r.difference
#   - frei0r.divide
#   - frei0r.dodge
#   - frei0r.grain_extract
#   - frei0r.grain_merge
#   - frei0r.hardlight
#   - frei0r.hue
#   - frei0r.lighten
#   - frei0r.multiply
#   - frei0r.overlay
#   - frei0r.saturation
#   - frei0r.screen
#   - frei0r.softlight
#   - frei0r.subtract
#   - frei0r.uvmap
#   - frei0r.value
#   - frei0r.xfade0r
#   - qtblend
#   - vqm
#   - affine
#   - movit.luma_mix
#   - movit.mix
#   - movit.overlay
#   - composite
#   - luma
#   - mix
#   - matte
#   - region
# ...

# %%
melt -query transitions frei0r.overlay
# Out:
# ---
# transitions:
#   - frei0r.addition
#   - frei0r.addition_alpha
#   - frei0r.alphaatop
#   - frei0r.alphain
#   - frei0r.alphainjection
#   - frei0r.alphaout
#   - frei0r.alphaover
#   - frei0r.alphaxor
#   - frei0r.blend
#   - frei0r.burn
#   - frei0r.cairoaffineblend
#   - frei0r.cairoblend
#   - frei0r.color_only
#   - frei0r.composition
#   - frei0r.darken
#   - frei0r.difference
#   - frei0r.divide
#   - frei0r.dodge
#   - frei0r.grain_extract
#   - frei0r.grain_merge
#   - frei0r.hardlight
#   - frei0r.hue
#   - frei0r.lighten
#   - frei0r.multiply
#   - frei0r.overlay
#   - frei0r.saturation
#   - frei0r.screen
#   - frei0r.softlight
#   - frei0r.subtract
#   - frei0r.uvmap
#   - frei0r.value
#   - frei0r.xfade0r
#   - qtblend
#   - vqm
#   - affine
#   - movit.luma_mix
#   - movit.mix
#   - movit.overlay
#   - composite
#   - luma
#   - mix
#   - matte
#   - region
# ...
