# %%
 was looking for hours for that you save my life literally . – 
Salem F
Dec 2, 2017 at 21:11
@bertieb This effect is working fine with only Landscape video and for square & portrait Images the video is playing in landscape

# %%
ls /home/jack/Desktop/HDD500/images/accident
# Out:
# 00001.jpg  00007.jpg  00013.jpg  00019.jpg  00025.jpg    Final_Endl.mp4
# 00002.jpg  00008.jpg  00014.jpg  00020.jpg  00026.jpg    output2.mp4
# 00003.jpg  00009.jpg  00015.jpg  00021.jpg  00027.jpg    slideshowSharp.mp4
# 00004.jpg  00010.jpg  00016.jpg  00022.jpg  00028.jpg    start.mp4
# 00005.jpg  00011.jpg  00017.jpg  00023.jpg  final2l.mp4
# 00006.jpg  00012.jpg  00018.jpg  00024.jpg  final5l.mp4

# %%
List="/home/jack/Desktop/HDD500/images/civitai/*.jpg"
Files=()

# Iterate over the files and add them to the array
for file in $List; do
    Files+=("$file")
done

# Take the first five files in the array
Files=("${Files[@]:0:5}")

# Use ffmpeg to create the video with zoompan effect
ffmpeg -framerate 1 -pattern_type glob -i "${Files[@]}" -vf "scale=8000:-1,zoompan=z='min(zoom+0.0005,1.5)':x='iw/2':y='ih/2-4000':d=300:s=512x512,crop=512:512:0:256" -c:v libx264 -pix_fmt yuv420p -r 24 -s 512x1024 -y women.mp4

# Play the output video using VLC (you can change this if needed)
vlc women.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
ffmpeg -t 10 -i /home/jack/Desktop/HDD500/images/accident/00007.jpg -t 10 -i /home/jack/Desktop/HDD500/images/accident/00008.jpg \
-filter_complex "[0:v]zoompan=z='if(lte(zoom,1.0),1.7,max(1.001,zoom-0.0045))':d=125,fade=t=out:st=4:d=1:scale=720x720[v0];[1:v]zoompan=z='if(lte(zoom,1.0),1.7,max(1.001,zoom-0.0045))':
d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1[v1]:scale=720x720;[v0][v1]concat=n=2:v=1:a=0,format=yuv420p[v]" -map [v] -s 720x720 -t 40 -preset ultrafast -y video2g5ss.mp4
vlc video2g5ss.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
ffmpeg -framerate 1 -pattern_type glob -i "/home/jack/Desktop/HDD500/images/civitai/*.jpg" -vf "scale=8000:-1,zoompan=z='min(zoom+0.0008,1.5)':x='iw/2':y='ih/2-4000':d=300:s=512x512,crop=512:512:0:256" -c:v libx264 -pix_fmt yuv420p -r 24 -s 512x1024 -y women8s.mp4
vlc women8s.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
ffmpeg -framerate 1 -pattern_type glob -i '/home/jack/Desktop/FlaskAppArchitect_Flask_App_Creator/static/images/shuffled_images/*.jpg' -vf "scale=8000:-1,zoompan=z='min(zoom+0.0005,1.5)':x='iw/2':y='ih/2-4000':d=300:s=512x1024,crop=512:1024:0:256" -c:v libx264 -pix_fmt yuv420p -r 24 -s 512x1024 -y queen2.mp4
vlc queen2.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
ls temp*.mp4
# Out:
# ls: cannot access 'temp*.mp4': No such file or directory
# : 2

# %%
#!/bin/bash

# Set the directory path
DIR="/home/jack/Desktop/HDD500/images/civitai"

# Log the directory and file paths
echo "Directory: $DIR"
echo "Image 1: $DIR/00001.jpg"
echo "Image 2: $DIR/00002.jpg"
echo "Image 3: $DIR/00003.jpg"
echo "Image 4: $DIR/00004.jpg"

# Create a text file listing the input files for the concat demuxer
echo "file 'temp_00001.mp4'" > filelist.txt
echo "file 'temp_00002.mp4'" >> filelist.txt
echo "file 'temp_00003.mp4'" >> filelist.txt
echo "file 'temp_00004.mp4'" >> filelist.txt

# Run ffmpeg with explicit aspect ratio setting and consistent zoompan parameters
ffmpeg \
-t 5 -i $DIR/00001.jpg -vf "zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=out:st=4:d=1,setpts=PTS+5/TB,setdar=1:1,scale=512:512" -y temp_00001.mp4 \
-t 5 -i $DIR/00002.jpg -vf "zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1,setpts=PTS+10/TB,setdar=1:1,scale=512:512" -y temp_00002.mp4 \
-t 5 -i $DIR/00003.jpg -vf "zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1,setpts=PTS+15/TB,setdar=1:1,scale=512:512" -y temp_00003.mp4 \
-t 5 -i $DIR/00004.jpg -vf "zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1,setpts=PTS+20/TB,setdar=1:1,scale=512:512" -y temp_00004.mp4

# Concatenate the temporary videos using the concat demuxer
ffmpeg -f concat -i filelist.txt -c copy -y out_fade2.mp4

# Log the completion of ffmpeg
echo "ffmpeg process completed."

# Play the output video using VLC (you can change this if needed)
vlc out_fade2.mp4

# Clean up temporary files
#rm temp_*.mp4 filelist.txt

# Log the completion of the script
echo "Script execution completed."
# Out:
# Directory: /home/jack/Desktop/HDD500/images/civitai
# Image 1: /home/jack/Desktop/HDD500/images/civitai/00001.jpg
# Image 2: /home/jack/Desktop/HDD500/images/civitai/00002.jpg
# Image 3: /home/jack/Desktop/HDD500/images/civitai/00003.jpg
# Image 4: /home/jack/Desktop/HDD500/images/civitai/00004.jpg
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
#!/bin/bash

# Set the directory path
DIR="/home/jack/Desktop/HDD500/images/civitai"

# Log the directory and file paths
echo "Directory: $DIR"
echo "Image 1: $DIR/00001.jpg"
echo "Image 2: $DIR/00002.jpg"
echo "Image 3: $DIR/00003.jpg"
echo "Image 4: $DIR/00004.jpg"

# Run ffmpeg with explicit aspect ratio setting and consistent zoompan parameters
ffmpeg \
-t 5 -i $DIR/00001.jpg -vf "zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=out:st=4:d=1,setdar=1:1,scale=512:512[v0]" -map "[v0]" -y temp_00001.mp4 \
-t 5 -i $DIR/00002.jpg -vf "zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1,setdar=1:1,scale=512:512[v1]" -map "[v1]" -y temp_00002.mp4 \
-t 5 -i $DIR/00003.jpg -vf "zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1,setdar=1:1,scale=512:512[v2]" -map "[v2]" -y temp_00003.mp4 \
-t 5 -i $DIR/00004.jpg -vf "zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1,setdar=1:1,scale=512:512[v3]" -map "[v3]" -y temp_00004.mp4

# Concatenate the temporary videos
ffmpeg -i "concat:temp_00001.mp4|temp_00002.mp4|temp_00003.mp4|temp_00004.mp4" -c copy -y out_fade.mp4

# Log the completion of ffmpeg
echo "ffmpeg process completed."

# Play the output video using VLC (you can change this if needed)
vlc out_fade.mp4

# Clean up temporary files
rm temp_*.mp4

# Log the completion of the script
echo "Script execution completed."
# Out:
# Directory: /home/jack/Desktop/HDD500/images/civitai
# Image 1: /home/jack/Desktop/HDD500/images/civitai/00001.jpg
# Image 2: /home/jack/Desktop/HDD500/images/civitai/00002.jpg
# Image 3: /home/jack/Desktop/HDD500/images/civitai/00003.jpg
# Image 4: /home/jack/Desktop/HDD500/images/civitai/00004.jpg
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
vlc out_fade.mp4
# Out:
# VLC media player 3.0.11.1 Vetinari (revision 3.0.11.1-0-g52483f3ca2)
# [0000000002370ec0] main libvlc: Running vlc with the default interface. Use 'cvlc' to use vlc without interface.
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# libva info: Trying to open /usr/lib/x86_64-linux-gnu/dri/nouveau_drv_video.so
# libva error: /usr/lib/x86_64-linux-gnu/dri/nouveau_drv_video.so has no function __vaDriverInit_0_32
# libva info: va_openDriver() returns -1
# [00007f8ad0001840] glconv_vaapi_x11 gl error: vaInitialize: unknown libva error
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# libva info: Trying to open /usr/lib/x86_64-linux-gnu/dri/gallium_drv_video.so
# libva info: va_openDriver() returns -1
# [00007f8ad0001840] glconv_vaapi_drm gl error: vaInitialize: unknown libva error
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# ...

# %%
#!/bin/bash

# Set the directory path
DIR="/home/jack/Desktop/HDD500/images/civitai"

# Log the directory and file paths
echo "Directory: $DIR"
echo "Image 1: $DIR/00001.jpg"
echo "Image 2: $DIR/00002.jpg"
echo "Image 3: $DIR/00003.jpg"
echo "Image 4: $DIR/00004.jpg"

# Run ffmpeg with scale filter to ensure square aspect ratio
ffmpeg \
-t 5 -i $DIR/00001.jpg \
-t 5 -i $DIR/00002.jpg \
-t 5 -i $DIR/00003.jpg \
-t 5 -i $DIR/00004.jpg \
-filter_complex \
"[0:v]zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=out:st=4:d=1,setsar=1,scale=512:512[v0]; \
 [1:v]zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1,setsar=1,scale=512:512[v1]; \
 [2:v]zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1,setsar=1,scale=512:512[v2]; \
 [3:v]zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1,setsar=1,scale=512:512[v3]; \
 [v0][v1][v2][v3]concat=n=4:v=1:a=0,format=yuv420p[v]" -map "[v]" -t 40 -y out_fade.mp4

# Log the completion of ffmpeg
echo "ffmpeg process completed."

# Play the output video using VLC (you can change this if needed)
vlc out_fade.mp4

# Log the completion of the script
echo "Script execution completed."
# Out:
# Directory: /home/jack/Desktop/HDD500/images/civitai
# Image 1: /home/jack/Desktop/HDD500/images/civitai/00001.jpg
# Image 2: /home/jack/Desktop/HDD500/images/civitai/00002.jpg
# Image 3: /home/jack/Desktop/HDD500/images/civitai/00003.jpg
# Image 4: /home/jack/Desktop/HDD500/images/civitai/00004.jpg
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
#!/bin/bash

# Set the directory path
DIR="/home/jack/Desktop/HDD500/images/civitai"

# Log the directory and file paths
echo "Directory: $DIR"
echo "Image 1: $DIR/00001.jpg"
echo "Image 2: $DIR/00002.jpg"
echo "Image 3: $DIR/00003.jpg"
echo "Image 4: $DIR/00004.jpg"

# Run ffmpeg with scale filter to ensure square aspect ratio
ffmpeg \
-t 5 -i $DIR/00001.jpg \
-t 5 -i $DIR/00002.jpg \
-t 5 -i $DIR/00003.jpg \
-t 5 -i $DIR/00004.jpg \
-filter_complex \
"[0:v]zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=out:st=4:d=1[v0]; \
 [1:v]zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1[v1]; \
 [2:v]zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1[v2]; \
 [3:v]zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1[v3]; \
 [v0][v1][v2][v3]concat=n=4:v=1:a=0,format=yuv420p,scale=512:512[v]" -map "[v]" -t 40 -y out_fade.mp4

# Log the completion of ffmpeg
echo "ffmpeg process completed."

# Play the output video using VLC (you can change this if needed)
vlc out_fade.mp4

# Log the completion of the script
echo "Script execution completed."
# Out:
# Directory: /home/jack/Desktop/HDD500/images/civitai
# Image 1: /home/jack/Desktop/HDD500/images/civitai/00001.jpg
# Image 2: /home/jack/Desktop/HDD500/images/civitai/00002.jpg
# Image 3: /home/jack/Desktop/HDD500/images/civitai/00003.jpg
# Image 4: /home/jack/Desktop/HDD500/images/civitai/00004.jpg
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
#!/bin/bash

# Set the directory path
DIR="/home/jack/Desktop/HDD500/images/civitai"

# Log the directory and file paths
echo "Directory: $DIR"
echo "Image 1: $DIR/00001.jpg"
echo "Image 2: $DIR/00002.jpg"
echo "Image 3: $DIR/00003.jpg"
echo "Image 4: $DIR/00004.jpg"

# Run ffmpeg with zoompan filter
ffmpeg \
-t 5 -i $DIR/00001.jpg \
-t 5 -i $DIR/00002.jpg \
-t 5 -i $DIR/00003.jpg \
-t 5 -i $DIR/00004.jpg \
-filter_complex \
"[0:v]zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=out:st=4:d=1[v0]; \
 [1:v]zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1[v1]; \
 [2:v]zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1[v2]; \
 [3:v]zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1[v3]; \
 [v0][v1][v2][v3]concat=n=4:v=1:a=0,format=yuv420p[v]" -map "[v]" -s "512x512" -t 40 -y out_fade.mp4

# Log the completion of ffmpeg
echo "ffmpeg process completed."

# Play the output video using VLC (you can change this if needed)
vlc out_fade.mp4

# Log the completion of the script
echo "Script execution completed."
# Out:
# Directory: /home/jack/Desktop/HDD500/images/civitai
# Image 1: /home/jack/Desktop/HDD500/images/civitai/00001.jpg
# Image 2: /home/jack/Desktop/HDD500/images/civitai/00002.jpg
# Image 3: /home/jack/Desktop/HDD500/images/civitai/00003.jpg
# Image 4: /home/jack/Desktop/HDD500/images/civitai/00004.jpg
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
#!/bin/bash

# Set the directory path
DIR="/home/jack/Desktop/HDD500/images/civitai"

# Log the directory and file paths
echo "Directory: $DIR"
echo "Image 1: $DIR/00001.jpg"
echo "Image 2: $DIR/00002.jpg"
echo "Image 3: $DIR/00003.jpg"
echo "Image 4: $DIR/00004.jpg"

# Run ffmpeg with zoompan filter and square aspect ratio
ffmpeg \
-t 5 -i $DIR/00001.jpg \
-t 5 -i $DIR/00002.jpg \
-t 5 -i $DIR/00003.jpg \
-t 5 -i $DIR/00004.jpg \
-filter_complex \
"[0:v]zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=out:st=4:d=1,setsar=1[v0]; \
 [1:v]zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1,setsar=1[v1]; \
 [2:v]zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1,setsar=1[v2]; \
 [3:v]zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1,setsar=1[v3]; \
 [v0][v1][v2][v3]concat=n=4:v=1:a=0,format=yuv420p[v]" -map "[v]" -s "512x512" -t 40 -y out_fade.mp4

# Log the completion of ffmpeg
echo "ffmpeg process completed."

# Play the output video using VLC (you can change this if needed)
vlc out_fade.mp4

# Log the completion of the script
echo "Script execution completed."
# Out:
# Directory: /home/jack/Desktop/HDD500/images/civitai
# Image 1: /home/jack/Desktop/HDD500/images/civitai/00001.jpg
# Image 2: /home/jack/Desktop/HDD500/images/civitai/00002.jpg
# Image 3: /home/jack/Desktop/HDD500/images/civitai/00003.jpg
# Image 4: /home/jack/Desktop/HDD500/images/civitai/00004.jpg
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
DIR="/home/jack/Desktop/HDD500/images/civitai"
echo $DIR"/00001.jpg"

ffmpeg \
-t 5 -i $DIR"/00001.jpg" \
-t 5 -i $DIR"/00002.jpg" \
-t 5 -i $DIR"/00003.jpg" \
-t 5 -i $DIR"/00004.jpg" \
-filter_complex \
"[0:v]zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=out:st=4:d=1[v0]:s=512x512; \
 [1:v]zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1[v1]:s=512x512; \
 [2:v]zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1[v2]:s=512x512; \
 [3:v]zoompan=z='if(lte(zoom,1.0),1.5,max(1.001,zoom-0.0015))':d=125,fade=t=in:st=0:d=1,fade=t=out:st=4:d=1[v3]:s=512x512; \
 [v0][v1][v2][v3]concat=n=4:v=1:a=0,format=yuv420p[v]" -map "[v]" -s "512x512" -t 40 -y out_fade.mp4
vlc out_fade.mp4
# Out:
# /home/jack/Desktop/HDD500/images/civitai/00001.jpg
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
vlc out_fade.mp4
# Out:
# VLC media player 3.0.11.1 Vetinari (revision 3.0.11.1-0-g52483f3ca2)
# [00000000011f9ec0] main libvlc: Running vlc with the default interface. Use 'cvlc' to use vlc without interface.
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# libva info: Trying to open /usr/lib/x86_64-linux-gnu/dri/nouveau_drv_video.so
# libva error: /usr/lib/x86_64-linux-gnu/dri/nouveau_drv_video.so has no function __vaDriverInit_0_32
# libva info: va_openDriver() returns -1
# [00007f987c006d70] glconv_vaapi_x11 gl error: vaInitialize: unknown libva error
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# libva info: Trying to open /usr/lib/x86_64-linux-gnu/dri/gallium_drv_video.so
# libva info: va_openDriver() returns -1
# [00007f987c006d70] glconv_vaapi_drm gl error: vaInitialize: unknown libva error
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# ...

# %%
https://www.mltframework.org/docs/meltedtesting/

# %%
You need to set the length of the image producer:

melt title-8.png length=300 in=0 out=299 clip-1.mp4
Also, in/out points are zero based. So to show 300 frames, out needs to be 299.

# %%
transition.geometry="0=0/0:100%x100%;74=-10%/-10%:120%x120%;75=-5%/-5%:110%x110%;149=0/0:110%x110%;150=0/-5%:110%x110%;224=-5%/0:110%x110%" \

# %%
#!/bin/bash

# Set the path to your image directory
#images="/home/jack/Desktop/HDD500/collections/images/Dali_woman/"
images="/home/jack/Desktop/HDD500/collections/images/yoday_dali/"
# Set the output resolution
output_resolution="512x768"

# Set the output video file path
output_file="${images}/512x768_output_videoEXP.mp4"

# Logging start
echo "Starting video processing..."

# Run melt command
melt \
"${images}/.all.jpg" ttl=75 \
-attach crop center=1 \
-attach affine transition.cycle=225 transition.geometry="0=0/0:100%x100%;74=-10%/-10%:120%x120%;75=-5%/-5%:90%x130%;149=0/0:110%x110%;150=0/-5%:90%x130%;224=-5%/0:90%x130%" \
-filter luma cycle=75 duration=25 \
-track /home/jack/Desktop/Ffmpeg/Cambodian-Odyssey/Odyssey.mp3 \
-transition mix \
-consumer avformat:"${output_file}" s=${output_resolution}

# Logging end
echo "Video processing complete. Output saved at: ${output_file}"
vlc ${output_file}
# Out:
# Starting video processing...
# [mp3 @ 0x564e8a083a80] Estimating duration from bitrate, this may be inaccurate
# [mp3 @ 0x564e8a0b2140] Estimating duration from bitrate, this may be inaccurate
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# |1=-10| |2= -5| |3= -2| |4= -1| |5=  0| |6=  1| |7=  2| |8=  5| |9= 10|
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# +---------------------------------------------------------------------+
# |               H = back 1 minute,  L = forward 1 minute              |
# |                 h = previous frame,  l = next frame                 |
# |           g = start of clip, j = next clip, k = previous clip       |
# |                0 = restart, q = quit, space = play                  |
# +---------------------------------------------------------------------+
# [libx264 @ 0x7f2d48001d00] interlace + weightp is not implemented
# ...

# %%
#!/bin/bash

# Set the path to your image directory
#images="/home/jack/Desktop/HDD500/collections/images/Dali_woman/"
images="/home/jack/Desktop/HDD500/collections/images/yoday_dali/"
# Set the output resolution
output_resolution="512x768"

# Set the output video file path
output_file="${images}/512x768_output_videoEXP01.mp4"

# Logging start
echo "Starting video processing..."

# Run melt command
melt \
"${images}/.all.jpg" ttl=75 \
-attach crop center=1 \
-attach affine transition.cycle=225 transition.geometry="0=0/0:90%x130%;174=-10%/-10%:120%x180%;75=-5%/-5%:90%x130%;149=0/0:110%x110%;150=0/-5%:90%x130%;224=-5%/0:90%x130%" \
-filter luma cycle=75 duration=25 \
-track /home/jack/Desktop/Ffmpeg/Cambodian-Odyssey/Odyssey.mp3 \
-transition mix \
-consumer avformat:"${output_file}" s=${output_resolution}

# Logging end
echo "Video processing complete. Output saved at: ${output_file}"
vlc ${output_file}
# Out:
# Starting video processing...
# [mp3 @ 0x56428e2dbc40] Estimating duration from bitrate, this may be inaccurate
# [mp3 @ 0x56428e2eb480] Estimating duration from bitrate, this may be inaccurate
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# |1=-10| |2= -5| |3= -2| |4= -1| |5=  0| |6=  1| |7=  2| |8=  5| |9= 10|
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# +---------------------------------------------------------------------+
# |               H = back 1 minute,  L = forward 1 minute              |
# |                 h = previous frame,  l = next frame                 |
# |           g = start of clip, j = next clip, k = previous clip       |
# |                0 = restart, q = quit, space = play                  |
# +---------------------------------------------------------------------+
# [libx264 @ 0x7f8864001d00] interlace + weightp is not implemented
# ...

# %%
images="/home/jack/Desktop/HDD500/collections/images/yoday_dali/"
output_file="${images}/512x768_output_videoEXP06.mp4"
# Set the output resolution
output_resolution="512x768"

melt "${images}/.all.jpg" ttl=100 \
-filter watermark:colour:black reverse=1 composite.geometry="0=15%/15%:10%/10%; 0.1625=0/0:100%x100%; -.1625=; -1=70%/70%:10%x10%" composite.mirror_off=1 composite.cycle=100 composite.fill=1 composite.valign=c composite.halign=c \
-consumer avformat:"${output_file}" s=${output_resolution}

# Logging end
echo "Video processing complete. Output saved at: ${output_file}"
vlc ${output_file}
# Out:
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# |1=-10| |2= -5| |3= -2| |4= -1| |5=  0| |6=  1| |7=  2| |8=  5| |9= 10|
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# +---------------------------------------------------------------------+
# |               H = back 1 minute,  L = forward 1 minute              |
# |                 h = previous frame,  l = next frame                 |
# |           g = start of clip, j = next clip, k = previous clip       |
# |                0 = restart, q = quit, space = play                  |
# +---------------------------------------------------------------------+
# [libx264 @ 0x7f5ef0001d00] interlace + weightp is not implemented
# [mp4 @ 0x7f5ef0000f40] Using AVStream.codec to pass codec parameters to muxers is deprecated, use AVStream.codecpar instead.
# [mp4 @ 0x7f5ef0000f40] Using AVStream.codec to pass codec parameters to muxers is deprecated, use AVStream.codecpar instead.
# ...

# %%
melt video.mp4 \
   -audio-track -blank 100 audio.mp3 \
   -transition mix in=100 out=500 a_track=0 b_track=1

# %%
#WORKING
output_file="512x768_EXP06.mp4"
# Set the output resolution
output_resolution="512x768"
melt /home/jack/Desktop/FlaskToys_flask_transitions/All_gifsx8.mp4  real_time="-4" an="1" -consumer avformat:Bl_Testv1.mp4 bf="0" color_range="pc" vcodec="libx265" rc="constqp" f="mp4" g="125" vq="15" top_field_first="2" mlt_service="avformat" deinterlacer="bwdif" rescale="bilinear" threads="5" audio_off="1" movflags="+faststart" vglobal_quality="15" -consumer avformat:"${output_file}" s=${output_resolution}
vlc output_file
# Out:
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x55b06eca3f80] Value 1.000000 for parameter 'seekable' out of range [-1 - 0]
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x55b06ecb3840] Value 1.000000 for parameter 'seekable' out of range [-1 - 0]
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x55b06ef97100] Value 1.000000 for parameter 'seekable' out of range [-1 - 0]
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x55b06ecc5040] Value 1.000000 for parameter 'seekable' out of range [-1 - 0]
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# |1=-10| |2= -5| |3= -2| |4= -1| |5=  0| |6=  1| |7=  2| |8=  5| |9= 10|
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# +---------------------------------------------------------------------+
# |               H = back 1 minute,  L = forward 1 minute              |
# |                 h = previous frame,  l = next frame                 |
# |           g = start of clip, j = next clip, k = previous clip       |
# ...

# %%
melt -query transitions
# Out:
# ---
# transitions:
#   - frei0r.addition
#   - frei0r.addition_alpha
#   - frei0r.alphaatop
#   - frei0r.alphain
#   - frei0r.alphainjection
#   - frei0r.alphaout
#   - frei0r.alphaover
#   - frei0r.alphaxor
#   - frei0r.blend
#   - frei0r.burn
#   - frei0r.cairoaffineblend
#   - frei0r.cairoblend
#   - frei0r.color_only
#   - frei0r.composition
#   - frei0r.darken
#   - frei0r.difference
#   - frei0r.divide
#   - frei0r.dodge
#   - frei0r.grain_extract
#   - frei0r.grain_merge
#   - frei0r.hardlight
#   - frei0r.hue
#   - frei0r.lighten
#   - frei0r.multiply
#   - frei0r.overlay
#   - frei0r.saturation
#   - frei0r.screen
#   - frei0r.softlight
#   - frei0r.subtract
#   - frei0r.uvmap
#   - frei0r.value
#   - frei0r.xfade0r
#   - qtblend
#   - vqm
#   - affine
#   - movit.luma_mix
#   - movit.mix
#   - movit.overlay
#   - composite
#   - luma
#   - mix
#   - matte
#   - region
# ...

# %%
#!/bin/bash

# Set the path to your image directory
#images="/home/jack/Desktop/HDD500/collections/images/Dali_woman/"
images="/home/jack/Desktop/HDD500/collections/images/yoday_dali/"
# Set the output resolution
output_resolution="512x768"

# Set the output video file path
output_file="512x768_EXP_001.mp4"

# Logging start
echo "Starting video processing..."

# Run melt command
melt \
"${images}/.all.jpg" ttl=75 \
-attach crop center=1 \
-attach affine transition.cycle=225 transition.geometry="0=0/0:100%x100%;174=-10%/-10%:100%x100%;75=-5%/-5%:100%x100%;149=0/0:100%x100%;150=0/-5%:100%x100%;224=-5%/0:100%x100%" \
-filter luma cycle=75 duration=25 \
-track /home/jack/Desktop/Ffmpeg/Cambodian-Odyssey/Odyssey.mp3 \
-transition mix \
-consumer avformat:"${output_file}" s=${output_resolution}

# Logging end
echo "Video processing complete. Output saved at: ${output_file}"
vlc ${output_file}
# Out:
# Starting video processing...
# [mp3 @ 0x563981ecad80] Estimating duration from bitrate, this may be inaccurate
# [mp3 @ 0x563981e48ec0] Estimating duration from bitrate, this may be inaccurate
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# |1=-10| |2= -5| |3= -2| |4= -1| |5=  0| |6=  1| |7=  2| |8=  5| |9= 10|
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# +---------------------------------------------------------------------+
# |               H = back 1 minute,  L = forward 1 minute              |
# |                 h = previous frame,  l = next frame                 |
# |           g = start of clip, j = next clip, k = previous clip       |
# |                0 = restart, q = quit, space = play                  |
# +---------------------------------------------------------------------+
# [libx264 @ 0x7fd5b4001cc0] interlace + weightp is not implemented
# ...

# %%
images="/home/jack/Desktop/HDD500/collections/images/yoday_dali/"
# Set the output video file path
output_file="512x768_EXP_004.mp4"
melt \
"${images}/.all.jpg" ttl=75 \
-attach crop center=1 \
-attach affine transition.cycle=300
transition.geometry="0=0/0:100%x100%;75=-10%/-10%:100%x100%;149=0/0:100%x100%;200=0/-5%:100%x100%;224=-5%/0:100%x100%" \
-filter luma cycle=75 duration=25 \
-track /home/jack/Desktop/Ffmpeg/Cambodian-Odyssey/Odyssey.mp3 \
-transition mix \
-consumer avformat:"${output_file}" s=${output_resolution}
# Out:
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# |1=-10| |2= -5| |3= -2| |4= -1| |5=  0| |6=  1| |7=  2| |8=  5| |9= 10|
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# +---------------------------------------------------------------------+
# |               H = back 1 minute,  L = forward 1 minute              |
# |                 h = previous frame,  l = next frame                 |
# |           g = start of clip, j = next clip, k = previous clip       |
# |                0 = restart, q = quit, space = play                  |
# +---------------------------------------------------------------------+
# Current Position:        176
# bash: transition.geometry=0=0/0:100%x100%;75=-10%/-10%:100%x100%;149=0/0:100%x100%;200=0/-5%:100%x100%;224=-5%/0:100%x100%: No such file or directory
# : 127

# %%
#!/bin/bash

# Set the path to your image directory
images="/home/jack/Desktop/HDD500/collections/images/yoday_dali/"
# Set the output resolution
output_resolution="512x768"

# Set the output video file path
output_file="512x768_EXP_002.mp4"

# Logging start
echo "Starting video processing..."

# Run melt command
melt \
"${images}/.all.jpg" ttl=75 \
-attach crop center=1 \
-attach affine transition.cycle=300
transition.geometry="0=0/0:100%x100%;75=-10%/-10%:100%x100%;149=0/0:100%x100%;200=0/-5%:100%x100%;224=-5%/0:100%x100%" \
-filter luma cycle=75 duration=25 \
-track /home/jack/Desktop/Ffmpeg/Cambodian-Odyssey/Odyssey.mp3 \
-transition mix \
-consumer avformat:"${output_file}" s=${output_resolution}

# Logging end
echo "Video processing complete. Output saved at: ${output_file}"
vlc ${output_file}
# Out:
# Starting video processing...
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# |1=-10| |2= -5| |3= -2| |4= -1| |5=  0| |6=  1| |7=  2| |8=  5| |9= 10|
# +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+ +-----+
# +---------------------------------------------------------------------+
# |               H = back 1 minute,  L = forward 1 minute              |
# |                 h = previous frame,  l = next frame                 |
# |           g = start of clip, j = next clip, k = previous clip       |
# |                0 = restart, q = quit, space = play                  |
# +---------------------------------------------------------------------+
# Current Position:         56
# bash: transition.geometry=0=0/0:100%x100%;75=-10%/-10%:100%x100%;149=0/0:100%x100%;200=0/-5%:100%x100%;224=-5%/0:100%x100%: No such file or directory
# Video processing complete. Output saved at: 512x768_EXP_002.mp4
# ...

# %%
DIR="/home/jack/Desktop/HDD500/collections/images/yoday_dali/"
melt images=@"$DIR*.jpg" -query "length" -query "fps=30"
# Out:
# ---
# consumers:
#   - jack
#   - gtk2_preview
#   - qglsl
#   - sdl
#   - sdl_audio
#   - sdl_preview
#   - sdl_still
#   - avformat
#   - blipflash
#   - decklink
#   - rtaudio
#   - xml
#   - sdi
#   - xgl
#   - cbrts
#   - sdl2
#   - sdl2_audio
#   - multi
#   - null
# ...
# ---
# filters:
#   - frei0r.3dflippo
#   - frei0r.B
#   - frei0r.G
#   - frei0r.IIRblur
#   - frei0r.R
#   - frei0r.alpha0ps
#   - frei0r.alphagrad
#   - frei0r.alphaspot
#   - frei0r.balanc0r
#   - frei0r.baltan
#   - frei0r.bgsubtract0r
#   - frei0r.bluescreen0r
#   - frei0r.brightness
#   - frei0r.bw0r
#   - frei0r.c0rners
#   - frei0r.cairogradient
#   - frei0r.cairoimagegrid
#   - frei0r.cartoon
#   - frei0r.cluster
#   - frei0r.colgate
#   - frei0r.coloradj_RGB
#   - frei0r.colordistance
#   - frei0r.colorhalftone
#   - frei0r.colorize
#   - frei0r.colortap
#   - frei0r.contrast0r
#   - frei0r.curves
#   - frei0r.d90stairsteppingfix
#   - frei0r.defish0r
#   - frei0r.delay0r
#   - frei0r.delaygrab
# ...

# %%
If the frame rate (fps) is 30 frames per second, and you start counting frames from 0, then 10 seconds of video would correspond to 10 seconds×30 frames/second=30010seconds×30frames/second=300 frames.

Since frame counting often starts from 0, the cycles would range from 0 to 299 for a 10-second video at 30 fps. So, the cycle at the 10-second mark would be 299 in this scenario.

In the context of video editing and transitions, a "cycle" typically refers to a specific frame or point in time within the video timeline. It represents a unit of progression in the sequence of frames that make up a video.

When you specify transition.cycle or a similar parameter in video editing software like in your melt command, you are indicating at which point in the video timeline a particular effect or transition should occur. Each frame in a video corresponds to a cycle, and the cycle number increases sequentially as the video progresses.

So, when you define transition.cycle=79, it means that the specified transition effect will start at the frame or cycle number 79 in your video. The interpretation of time in cycles depends on the frame rate of your video. For example, if your video has a frame rate of 30 frames per second, then cycle 79 would correspond to approximately 2.63 seconds into the video (79 cycles / 30 frames per second).

Understanding cycles is crucial for precisely timing and synchronizing visual effects, transitions, or any changes you want to apply to your video at specific points in time.

A the cycles from 0 to 79 are designated to do nothing, and the transition starts at cycle 79. The behavior of the transition at cycle 79 is as follows:
at cycle 79, a translation is applied to the video. It translates by 10% of its width and height in the negative direction (-10%/-10%), effectively shifting the video up and to the left.
    The size of the video is maintained at 100% of the original size (100%x100%).

In summary, at cycle 79, a noticeable shift upward and to the left should occur in the video due to the specified translation values.
    At cycle 149, the video returns to its original position and size.
    At cycle 200, a slight translation of 5% of the height in the negative direction is applied, effectively shifting the video upward.
    At cycle 224, a translation of 5% of the width in the negative direction is applied, shifting the video to the left.

This sequence suggests a smooth transition where the video returns to its original position at cycle 149 and then introduces a gradual upward and leftward shift in subsequent cycles.

Feel free to adjust the values further based on your preferences and the desired visual outcome. If you have any more questions or if there's anything else you'd like assistance with, let me know!

# %%
vlc ${output_file}
# Out:
# VLC media player 3.0.11.1 Vetinari (revision 3.0.11.1-0-g52483f3ca2)
# [00000000015efec0] main libvlc: Running vlc with the default interface. Use 'cvlc' to use vlc without interface.
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# libva info: Trying to open /usr/lib/x86_64-linux-gnu/dri/nouveau_drv_video.so
# libva error: /usr/lib/x86_64-linux-gnu/dri/nouveau_drv_video.so has no function __vaDriverInit_0_32
# libva info: va_openDriver() returns -1
# [00007fab58001840] glconv_vaapi_x11 gl error: vaInitialize: unknown libva error
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# libva info: Trying to open /usr/lib/x86_64-linux-gnu/dri/gallium_drv_video.so
# libva info: va_openDriver() returns -1
# [00007fab58001840] glconv_vaapi_drm gl error: vaInitialize: unknown libva error
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# ...

# %%
#WORKING
output_file="512x768_EXP06.mp4"
# Set the output resolution
output_resolution="512x768"
melt /home/jack/Desktop/FlaskToys_flask_transitions/All_gifsx8.mp4 bf="0" color_range="pc" vcodec="libx265" rc="constqp" f="mp4" g="125" vq="15" top_field_first="2" mlt_service="avformat" deinterlacer="bwdif" rescale="bilinear" threads="5" audio_off="1" movflags="+faststart" vglobal_quality="15" -consumer avformat:"${output_file}" s=${output_resolution}
vlc output_file
